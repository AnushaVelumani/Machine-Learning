# %% [markdown]
# #### 1.4 (a)  Generate a linearly separable data set of size 20. Plot the examples { (xn , Yn ) } as well as the target function f on a plane. Be sure to mark the examples from different classes differently, and add labels to the axes of the plot.

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['axes.unicode_minus'] = False 

#generate a data set of 20. 
#for simplicity, 10 in the first quadrant, another 10 in the third quadrant 

X1 = []
Y1 = []
X2 = []
Y2 = []

for i in range(10):
    X1.append(random.uniform(0,1))
    Y1.append(random.uniform(0,1))
    X2.append(random.uniform(-1,0))
    Y2.append(random.uniform(-1,0))

#label the data
data1 = [np.array([1,X1[i],Y1[i],1]) for i in range(10)]
data2 = [np.array([1,X2[i],Y2[i],-1]) for i in range(10)]
data = data1 + data2

plt.figure(figsize=(8,6), dpi=60)

for i in range(20):
    if (data[i][3] == 1):
        plt.plot(data[i][1], data[i][2], 'ro')
    elif (data[i][3] ==-1):
        plt.plot (data[i][1], data[i][2], 'bo')
        
plt.xlabel('X')
plt.ylabel('Y')
plt.plot([-0.5,0.5], [1,-1], 'r-')

plt.show()

X = []

Y = []

for i in range(20):
    Y.append(data[i][3])
#print(Y)

for i in range(20):
    X.append(data[i][:3])

# %% [markdown]
# #### 1.4 (b) Run the perceptron learning algorithm on the data set a bove. Report the number of updates that the algorith m takes before convergi ng. Plot the examples { (xn , Yn) } , the target function f , and the final hypothesis g in the same figure . Comment on whether f is close to g.

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['axes.unicode_minus'] = False 

#generate a data set of 20. 
#for simplicity, 10 in the first quadrant, another 10 in the third quadrant 

X1 = []
Y1 = []
X2 = []
Y2 = []

for i in range(10):
    X1.append(random.uniform(0,1))
    Y1.append(random.uniform(0,1))
    X2.append(random.uniform(-1,0))
    Y2.append(random.uniform(-1,0))

#label the data
data1 = [np.array([1,X1[i],Y1[i],1]) for i in range(10)]
data2 = [np.array([1,X2[i],Y2[i],-1]) for i in range(10)]
data = data1 + data2

plt.figure(figsize=(8,6), dpi=60)

X = []

Y = []

for i in range(20):
    Y.append(data[i][3])
#print(Y)

for i in range(20):
    X.append(data[i][:3])
    
#The perceptron algorithm to find the weight and calculate exact target function
def Perceptron(X, Y):

    weights = []
    w0=0
    w1= random.uniform(-.1,.1)
    w2 = random.uniform(-.1,.10)
    weights.append(w0)
    weights.append(w1)
    weights.append(w2)
   
    iteration = 0


    for i, n in enumerate(X):
        predicted_y = np.sign(np.dot(np.transpose(weights), X[i]))   # y' = w^T * X
        actual_y = Y[i]
        if predicted_y == actual_y:
            weights = weights
        else:
            iteration = iteration + 1
            weights = weights + X[i]*Y[i]
                   
    print("PLA took " + str(iteration) + " iterations to converge")
    return weights


z = Perceptron(X,Y)

w0 = z[0]
w1 = z[1]
w2 = z[2]

slope = -w1/w2
intercept = -w0/w2


def abline(slope, intercept):
     # Plot a line from slope and intercept
     ax = plt.gca()
     x_value = np.array(ax.get_xlim())
     y_value = intercept + slope * x_value
     plt.plot(x_value, y_value, '--')

abline(slope,intercept)           

for i in range(20):
    if (data[i][3] == 1):
        plt.plot(data[i][1], data[i][2], 'ro')
    elif (data[i][3] ==-1):
        plt.plot (data[i][1], data[i][2], 'bo')
        

plt.xlabel('X')
plt.ylabel('Y')        
plt.plot([-1,1], [1,-1], 'r-')

plt.show()
# Out:
# PLA took 2 iterations to converge

# %% [markdown]
# #### From the above graph, we may notice that g is close to target function but not identical.

# %% [markdown]
# #### 1.4 c) Repeat everything in (b) with another randomly generated data set of size 20. Compare your results with (b ).

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['axes.unicode_minus'] = False 

#generate a data set of 20. 
#for simplicity, 10 in the first quadrant, another 10 in the third quadrant 

X1 = []
Y1 = []
X2 = []
Y2 = []

for i in range(10):
    X1.append(random.uniform(0,1))
    Y1.append(random.uniform(0,1))
    X2.append(random.uniform(-1,0))
    Y2.append(random.uniform(-1,0))

#label the data
data1 = [np.array([1,X1[i],Y1[i],1]) for i in range(10)]
data2 = [np.array([1,X2[i],Y2[i],-1]) for i in range(10)]
data = data1 + data2

plt.figure(figsize=(8,6), dpi=60)

X = []

Y = []

for i in range(20):
    Y.append(data[i][3])
#print(Y)

for i in range(20):
    X.append(data[i][:3])
    
#The perceptron algorithm to find the weight and calculate exact target function
def Perceptron(X, Y):

    weights = []
    w0=0
    w1= random.uniform(-.10,.10)     # generating random weights
    w2 = random.uniform(-.10,.10)
    weights.append(w0)
    weights.append(w1)
    weights.append(w2)
   
    iteration = 0

    
    for i, n in enumerate(X):
        predicted_y = np.sign(np.dot(np.transpose(weights), X[i]))   # y' = w^T * X
        actual_y = Y[i]
        if predicted_y == actual_y:
            weights = weights
        else:
            iteration = iteration + 1
            weights = weights + X[i]*Y[i]
                   
    print("PLA took " + str(iteration) + " iterations to converge")
    return weights


z = Perceptron(X,Y)

w0 = z[0]
w1 = z[1]
w2 = z[2]

slope = -w1/w2
intercept = -w0/w2


def abline(slope, intercept):
     # Plot a line from slope and intercept
     ax = plt.gca()
     x_value = np.array(ax.get_xlim())
     y_value = intercept + slope * x_value
     plt.plot(x_value, y_value, '--')

abline(slope,intercept)           

for i in range(20):
    if (data[i][3] == 1):
        plt.plot(data[i][1], data[i][2], 'ro')
    elif (data[i][3] ==-1):
        plt.plot (data[i][1], data[i][2], 'bo')
        
plt.xlabel('X')
plt.ylabel('Y')         
plt.plot([-1,1], [1,-1], 'r-')

plt.show()
# Out:
# PLA took 2 iterations to converge

# %% [markdown]
# #### From the above graph, we may notice that g is close to target function but not identical.

# %% [markdown]
# #### 1.4 d) Repeat everything in (b) with another randomly generated data set of size 100. Compare your results with (b).

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['axes.unicode_minus'] = False 

#generate a data set of 100. 
#for simplicity, 50 in the first quadrant, another 50 in the third quadrant 

X1 = []
Y1 = []
X2 = []
Y2 = []

for i in range(50):
    X1.append(random.uniform(0,1))
    Y1.append(random.uniform(0,1))
    X2.append(random.uniform(-1,0))
    Y2.append(random.uniform(-1,0))

#label the data
data1 = [np.array([1,X1[i],Y1[i],1]) for i in range(50)]
data2 = [np.array([1,X2[i],Y2[i],-1]) for i in range(50)]
data = data1 + data2

plt.figure(figsize=(8,6), dpi=60)

X = []

Y = []

for i in range(100):
    Y.append(data[i][3])
#print(Y)

for i in range(100):
    X.append(data[i][:3])
    
#The perceptron algorithm to find the weight and calculate exact target function
def Perceptron(X, Y):

    weights = []
    w0=0
    w1= random.uniform(-.1,.1)      # generating random weights
    w2 = random.uniform(-.1,.1)
    weights.append(w0)
    weights.append(w1)
    weights.append(w2)
   
    iteration = 0

    
    for i, n in enumerate(X):
        predicted_y = np.sign(np.dot(np.transpose(weights), X[i]))    # y' = w^T *X  
        actual_y = Y[i]
        if predicted_y == actual_y:
            weights = weights
        else:
            iteration = iteration + 1
            weights = weights + X[i]*Y[i]
                   
    print("PLA took " + str(iteration) + " iterations to converge")
    return weights


z = Perceptron(X,Y)
print(z)

w0 = z[0]
w1 = z[1]
w2 = z[2]

slope = -w1/w2
intercept = -w0/w2


def abline(slope, intercept):
     # Plot a line from slope and intercept
     ax = plt.gca()
     x_value = np.array(ax.get_xlim())
     y_value = intercept + slope * x_value
     plt.plot(x_value, y_value, '--')

abline(slope,intercept)  

for i in range(100):
    if (data[i][3] == 1):
        plt.plot(data[i][1], data[i][2], 'ro')
    elif (data[i][3] ==-1):
        plt.plot (data[i][1], data[i][2], 'bo')
        

plt.xlabel('X')
plt.ylabel('Y')         
plt.plot([-1,1], [1,-1], 'r-')

plt.show()
# Out:
# PLA took 2 iterations to converge
# [0.         1.03459198 0.81810634]

# %% [markdown]
# #### g is closer to target function than 1.4 b and c

# %% [markdown]
# #### 1.4 e) Repeat everything in (b) with another random ly generated data set of size 1,000. Compare your results with (b ).

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['axes.unicode_minus'] = False 

#generate a data set of 100. 
#for simplicity, 50 in the first quadrant, another 50 in the third quadrant 

X1 = []
Y1 = []
X2 = []
Y2 = []

for i in range(500):
    X1.append(random.uniform(0,1))
    Y1.append(random.uniform(0,1))
    X2.append(random.uniform(-1,0))
    Y2.append(random.uniform(-1,0))

#label the data
data1 = [np.array([1,X1[i],Y1[i],1]) for i in range(500)]
data2 = [np.array([1,X2[i],Y2[i],-1]) for i in range(500)]
data = data1 + data2

plt.figure(figsize=(8,6), dpi = 60)

X = []

Y = []

for i in range(1000):
    Y.append(data[i][3])
#print(Y)

for i in range(1000):
    X.append(data[i][:3])
    
#The perceptron algorithm to find the weight and calculate exact target function
def Perceptron(X, Y):

    weights = []
    w0=0
    w1= random.uniform(-.10,.10)     # generating random weights
    w2 = random.uniform(-.10,.10)
    weights.append(w0)
    weights.append(w1)
    weights.append(w2)
   
    iteration = 0

   
    for i, n in enumerate(X):
        predicted_y = np.sign(np.dot(np.transpose(weights), X[i]))    # y' = w^T *X  
        actual_y = Y[i]
        if predicted_y == actual_y:
            weights = weights
        else:
            iteration = iteration + 1
            weights = weights + X[i]*Y[i]
                   
    print("PLA took " + str(iteration) + " iterations to converge")
    return weights


z = Perceptron(X,Y)
print(z)

w0 = z[0]
w1 = z[1]
w2 = z[2]

slope = -w1/w2
intercept = -w0/w2


def abline(slope, intercept):
     # Plot a line from slope and intercept
     ax = plt.gca()
     x_value = np.array(ax.get_xlim())
     y_value = intercept + slope * x_value
     plt.plot(x_value, y_value, '--')

abline(slope,intercept)  

for i in range(1000):
    if (data[i][3] == 1):
        plt.plot(data[i][1], data[i][2], 'ro')
    elif (data[i][3] ==-1):
        plt.plot (data[i][1], data[i][2], 'bo')
        
plt.xlabel('X')
plt.ylabel('Y')         
plt.plot([-1,1], [1,-1], 'r-')

plt.show()
# Out:
# PLA took 2 iterations to converge
# [0.         0.96071513 1.06708939]

# %% [markdown]
# #### g is closer to target function than b,c and d

# %% [markdown]
# ## Note : Due to randomness of weights and data set, g changes everytime while running the program
