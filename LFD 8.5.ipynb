# %% [markdown]
# #### a,b) Generate 6 classified points and plot g random and g svm

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus'] = False 

#generate a data set of 6. 
#for simplicity, 3 in the first quadrant, another 3 in the third quadrant 
X1 = []
Y1 = []
X2 = []
Y2 = []


for i in range(3):
    X1.append(random.uniform(0,1))
    Y1.append(random.uniform(0,1))
    X2.append(random.uniform(-1,0))
    Y2.append(random.uniform(-1,0))
    

    
#label the data
data1 = [np.array([X1[i],Y1[i],1]) for i in range(3)]

data2 = [np.array([X2[i],Y2[i],-1]) for i in range(3)]

data = data1 + data2


X_= np.array(data)[:,1:2]


Y_= np.array(data)[:,2:3]


plt.plot(X1,Y1,'ro',X2,Y2,'bo') #plotting the data points

i = 0

def g_random():
    while True:
        a=random.uniform(-1,1)
        for i in range(6):        
            if((np.sign(X_[i]-a)*Y_[i])>0):
                i=1
            else:
                i=-1
                break
                
        if(i==1):
            return a
            break
        
a_random=g_random()
plt.axhline(y=a_random)
plt.show()

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['axes.unicode_minus'] = False 
from sklearn.svm import SVC
from mlxtend.plotting import plot_decision_regions


X1 = []
Y1 = []
X2 = []
Y2 = []

 
for i in range(6):
    X1.append(random.uniform(0,1))
    Y1.append(random.uniform(0,1))
    X2.append(random.uniform(-1,1))
    Y2.append(random.uniform(-1,0))
    
    #label the data
data1 = [np.array([1,X1[i],Y1[i],1]) for i in range(3)]
data2 = [np.array([1,X2[i],Y2[i],-1]) for i in range(3)]
data = data1 + data2

X = []
Y = []

for i in range(6):
    Y.append(data[i][3])

for i in range(6):
    X.append([data[i][1], data[i][2]])


X = np.asarray(X)
model =SVC(kernel = 'linear', C=1000)
model.fit(X,Y)
#print(X.shape)


ymin, ymax = plt.ylim(-1,1)
xlim,xmax = plt.xlim(-1,1)

for i in range(6):
    if (data[i][3] == 1):
        plt.plot(data[i][1], data[i][2], 'ro')
    elif (data[i][3] ==-1):
        plt.plot (data[i][1], data[i][2], 'bo')


w = model.coef_[0]
xlim,xmax = plt.xlim(-1,1)
a = -w[0] / w[1]
xx = np.linspace(ymin, ymax)
yy = a * xx - (model.intercept_[0]) / w[1]
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T

Z = model.decision_function(xy).reshape(XX.shape)
plt.contour(xx, yy,Z,colors='black', levels=[-1, 0,1], alpha=0.3,linestyles=['--', '-', '--'])

# %% [markdown]
# #### c) Repeat (a) for a million points

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['axes.unicode_minus'] = False 
from sklearn.svm import SVC
from mlxtend.plotting import plot_decision_regions


#generate a data set of 1000. 

X1 = []
Y1 = []
X2 = []
Y2 = []

 
for i in range(1000000):
    X1.append(random.uniform(0,1))
    Y1.append(random.uniform(0,1))
    X2.append(random.uniform(-1,1))
    Y2.append(random.uniform(-1,0))
    
    #label the data
data1 = [np.array([X1[i],Y1[i],1]) for i in range(500000)]
data2 = [np.array([X2[i],Y2[i],-1]) for i in range(500000)]
data = data1 + data2


data1 = [np.array([X1[i],Y1[i],1]) for i in range(3)]
data2 = [np.array([X2[i],Y2[i],-1]) for i in range(3)]
data = data1 + data2

X_= np.array(data)[:,1:2]


Y_= np.array(data)[:,2:3]


plt.plot(X1,Y1,'ro',X2,Y2,'bo') #plotting the data points

i = 0

def g_random():
    while True:
        a=random.uniform(-1,1)
        for i in range(6):        
            if((np.sign(X_[i]-a)*Y_[i])>0):
                i=1
            else:
                i=-1
                break
                
        if(i==1):
            return a
            break
        
a_random=g_random()
plt.axhline(y=a_random)
plt.show()



##############################################################################################################

X = np.asarray(X)
model =SVC(kernel = 'linear', C=1000)
model.fit(X,Y)

w = model.coef_[0]
xlim,xmax = plt.xlim(-1,1)
a = -w[0] / w[1]
xx = np.linspace(ymin, ymax)
yy = a * xx - (model.intercept_[0]) / w[1]
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T


Z = model.decision_function(xy).reshape(XX.shape)
plt.contour(xx, yy,Z,colors='black', levels=[-0.5, 0, 0.5], alpha=0.3,linestyles=['--', '-', '--'])


#################################################################################################################

# %% [markdown]
# ### Due to a huge data set, the system was not able to generate and plot the data. It took a very long time and so had to abort the program.

# %% [markdown]
# #### d) Histogram for grandom and gsvm

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus'] = False 

#generate a data set of 20. 
#for simplicity, 10 in the first quadrant, another 10 in the third quadrant 
X1 = []
Y1 = []
X2 = []
Y2 = []
label=[]

for i in range(3):
    X1.append(random.uniform(0,1))
    Y1.append(random.uniform(0,1))
    X2.append(random.uniform(-1,0))
    Y2.append(random.uniform(-1,0))
    

    
#label the data
data1 = [np.array([X1[i],Y1[i],1]) for i in range(3)]

data2 = [np.array([X2[i],Y2[i],-1]) for i in range(3)]

data = data1 + data2


X_= np.array(data)[:,1:2]


Y_= np.array(data)[:,2:3]

i = 0

def g_random():
    while True:
        a=random.uniform(-1,1)
        for i in range(6):        
            if((np.sign(X_[i]-a)*Y_[i])>0):
                i=1
            else:
                i=-1
                break
                
        if(i==1):
            return a
            break
        
a_random=g_random()

X = np.asarray(X)
model =SVC(kernel = 'linear', C=1000)
model.fit(X,Y)
w = model.coef_[0]
xlim,xmax = plt.xlim(-1,1)
a = -w[0] / w[1]
xx = np.linspace(ymin, ymax)
yy = a * xx - (model.intercept_[0]) / w[1]
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T

Z = model.decision_function(xy).reshape(XX.shape)
a_svm = a


alpha_random=[]
alpha_svm=[]
for k in range(1000):
    X1 = []
    Y1 = []
    X2 = []
    Y2 = []

    for i in range(3):
        X1.append(random.uniform(0,1))
        Y1.append(random.uniform(0,1))
        X2.append(random.uniform(-1,0))
        Y2.append(random.uniform(-1,0))

    #label the data
    data1 = [np.array([X1[i],Y1[i],1]) for i in range(3)]

    data2 = [np.array([X2[i],Y2[i],-1]) for i in range(3)]

    data = data1 + data2

    X_= np.array(data)[:,1:2]


Y_= np.array(data)[:,2:3]

i = 0

def g_random():
    while True:
        a=random.uniform(-1,1)
        for i in range(6):        
            if((np.sign(X_[i]-a)*Y_[i])>0):
                i=1
            else:
                i=-1
                break
                
        if(i==1):
            return a
            break

    a_random=g_random()
    
    alpha_random.append(a_random)
    
    while True:
        a=g_random()
        flag= distances(a)
        if flag==1:
            break

    a_svm=a
    alpha_svm.append(a_svm)
    
plt.hist(a_rand,bins='auto')
plt.show()

plt.hist(a_sv,bins='auto')
plt.show()

# %% [markdown]
# ####  Inference from the histograms, the histogram for random and svm are distributed well and look alike except for a small variation. random is pointed in the center whereas svm is more of a bell curve.
